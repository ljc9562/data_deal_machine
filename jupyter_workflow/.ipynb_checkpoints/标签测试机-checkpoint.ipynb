# %%
import pandas as pd
import os
os.chdir(r'C:\\Users\\Administrator\\PycharmProjects\\untitled1\\data_deal_machine')
from pydata_deal_machine.wetagging_machine import Wetagging
from pydata_deal_machine.welookup_machine import welookup
from pydata_deal_machine.wetagging_machine import Wetagging,Wetagging_create
from pydata_deal_machine.wedtclean_machine import Date_deal

# %%
os.listdir('.\config\Tagcode_home')
# Out:
# ['00001.txt', '00002.txt', '00003.txt', '00008.txt', '00009.txt', '00010.txt']

# %%
create = Wetagging_create("re",'00010.txt')
# Out:
# 该标签文件已存在,请重新命名

# %%
data = pd.read_hdf(path_or_buf = r"F:\temp\automation\new_tot_table\output\tot_data.h5")

# %%
data = data.loc[:,['婚博会id','婚礼日期']]

# %%
dt_result = Date_deal(frame=data,name='婚礼日期',key='婚博会id',aim_data).summary()

# %%
dt_result
# Out:
#           婚博会id        婚礼日期       日期格式化 中文备注   相差数
# 0      22258000                    None        NaN
# 1      22258002                    None        NaN
# 2      22258004                    None        NaN
# 3      22258005                    None        NaN
# 4      22258006                    None        NaN
# 5      22258008                    None        NaN
# 6      22258009                    None        NaN
# 7      22258010                    None        NaN
# 8      22258012                    None        NaN
# 9      22258013                    None        NaN
# 10     22258014                    None        NaN
# 11     22258015                    None        NaN
# 12     22258019                    None        NaN
# 13     22258020                    None        NaN
# 14     22258022                    None        NaN
# 15     22258023                    None        NaN
# 16     22258026                    None        NaN
# ...
